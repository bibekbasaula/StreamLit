# %%
# 17 number decimal point

b = 0.1234567890123456789
print(b)
# Out:
# 0.12345678901234568

# %%
(1.1 + 2.2 ) == 3.3
# Out:
# False

# %%
1.1 + 2.2
# Out:
# 3.3000000000000003

# %%
from decimal import Decimal as F # alias F
print(F('1.1') + Decimal('2.2'))
# Out:
# 3.3

# %%
import decimal
print(decimal.Decimal('1.1') + decimal.Decimal('2.2'))
# Out:
# 3.3

# %%
import math
(
print(math.pi),
print(math.sqrt(4)),
print(math.cos(math.pi)),
print(math.sin(math.pi)),
print(math.exp(10)),
print(math.log10(1000)),
print(math.factorial(6))
)
# Out:
# 3.141592653589793
# 2.0
# -1.0
# 1.2246467991473532e-16
# 22026.465794806718
# 3.0
# 720
# None None None None None None None

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/math.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
import random
x = [ 'a', 'b', 'c', 'd', 'e',]
print(random.choice(x))
# Out:
# b

# %%
import random
x = [ 'messi', 'ronaldo', 'neymar']
random.shuffle(x)
print(x)
# Out:
# ['ronaldo', 'neymar', 'messi']

# %%
print(random.randrange(10, 20))
# Out:
# 16

# %%
print(random.random())
# Out:
# 0.4911140811442867

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
# decimal, math, random, => modules in python =>standard library

# %%
s = 'This is string'
print( s[0] , type(s))
# Out:
# T <class 'str'>

# %%
s[8]
# Out:
# 's'

# %%
s = 'This is string. Strings in python are immutable.'
s[-2] # negative indexing
s[46]
# Out:
# 'e'

# %%
s[0:4] # slicing
# Out:
# 'This'

# %%
s[5:12], s[5:-23]
# Out:
# ('is stri', 'is string. Strings i')

# %%
s[-10:]
# Out:
# 'immutable.'

# %%
s[0:14:2] # start : stop : step
# Out:
# 'Ti ssrn'

# %%
s[-1::-1]
# Out:
# '.elbatummi era nohtyp ni sgnirtS .gnirts si sihT'
