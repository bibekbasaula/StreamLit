# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('ncr_ride_bookings.csv')
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
df.describe()
# Out:
#             Avg VTAT       Avg CTAT  Cancelled Rides by Customer  \
# count  139500.000000  102000.000000                      10500.0
# mean        8.456352      29.149636                          1.0
# std         3.773564       8.902577                          0.0
# min         2.000000      10.000000                          1.0
# 25%         5.300000      21.600000                          1.0
# 50%         8.300000      28.800000                          1.0
# 75%        11.300000      36.800000                          1.0
# max        20.000000      45.000000                          1.0
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                    27000.0            9000.0  102000.000000
# mean                         1.0               1.0     508.295912
# std                          0.0               0.0     395.805774
# min                          1.0               1.0      50.000000
# ...

# %%
df.size
# Out:
# 3150000

# %%
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df = df.dropna(subset=["Ride Distance"]).reset_index(drop=True)

# %%
df = df.dropna(subset=["Driver Ratings"]).reset_index(drop=True)

# %%
df = df.dropna(subset=["Customer Rating"]).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Date                                     0
# Time                                     0
# Booking ID                               0
# Booking Status                           0
# Customer ID                              0
# Vehicle Type                             0
# Pickup Location                          0
# Drop Location                            0
# Avg VTAT                                 0
# Avg CTAT                                 0
# Cancelled Rides by Customer          93000
# Reason for cancelling by Customer    93000
# Cancelled Rides by Driver            93000
# Driver Cancellation Reason           93000
# Incomplete Rides                     93000
# Incomplete Rides Reason              93000
# Booking Value                            0
# Ride Distance                            0
# Driver Ratings                           0
# Customer Rating                          0
# Payment Method                           0
# dtype: int64

# %%
lr = LabelEncoder()
codeVehicle = lr.fit_transform(df['Vehicle Type'])

# %%
np.unique(codeVehicle)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
df['codeVehicle'] = codeVehicle

# %%
import pandas as pd

# Convert Time column to datetime, parsing hours, minutes, seconds
df['Time_dt'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')

# %%
df['hour'] = df['Time_dt'].dt.hour

# %%
def part_of_day(hour):
    if 5 <= hour < 12:
        return 0  # morning
    elif 12 <= hour < 17:
        return 1  # afternoon
    elif 17 <= hour < 21:
        return 2  # evening
    else:
        return 3  # night

df['part_of_day'] = df['hour'].apply(part_of_day)

# %%
codePay = lr.fit_transform(df['Payment Method'])

# %%
df['codePay'] = codePay

# %%
df
# Out:
#              Date      Time    Booking ID Booking Status   Customer ID  \
# 0      2024-08-23  08:56:10  "CNR8494506"      Completed  "CID9202816"
# 1      2024-10-21  17:17:25  "CNR8906825"      Completed  "CID2610914"
# 2      2024-09-16  22:08:00  "CNR1950162"      Completed  "CID9933542"
# 3      2024-02-06  09:44:56  "CNR4096693"      Completed  "CID4670564"
# 4      2024-06-17  15:45:58  "CNR2002539"      Completed  "CID6800553"
# ...           ...       ...           ...            ...           ...
# 92995  2024-11-11  19:34:01  "CNR6500631"      Completed  "CID4337371"
# 92996  2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 92997  2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
# 92998  2024-10-05  07:53:34  "CNR3030099"      Completed  "CID9415487"
# 92999  2024-03-10  15:38:03  "CNR3447390"      Completed  "CID4108667"
#
#         Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
np.unique(codePay)
# Out:
# array([0, 1, 2, 3, 4])

# %%
df = df.reset_index(drop=True)

# %%
dfx = df[['codeVehicle', 'Ride Distance','Avg VTAT','Avg CTAT']]
dfx.head()
# Out:
#    codeVehicle  Ride Distance  Avg VTAT  Avg CTAT
# 0            0          13.58      13.4      25.8
# 1            4          34.02      13.1      28.5
# 2            1          48.21       5.3      19.6
# 3            0           4.85       5.1      18.1
# 4            2          41.24       7.1      20.4

# %%
dfpca = dfx[['Ride Distance','Avg VTAT','Avg CTAT']]

# %%
dfpca
# Out:
#        Ride Distance  Avg VTAT  Avg CTAT
# 0              13.58      13.4      25.8
# 1              34.02      13.1      28.5
# 2              48.21       5.3      19.6
# 3               4.85       5.1      18.1
# 4              41.24       7.1      20.4
# ...              ...       ...       ...
# 92995          40.08      10.2      44.4
# 92996          21.31       5.1      30.8
# 92997          15.93       2.7      23.4
# 92998          45.54       6.9      39.6
# 92999          21.19       3.5      33.7
#
# [93000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sl = StandardScaler()
dfpcas = sl.fit_transform(dfpca)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
df_pca = pca.fit_transform(dfpcas)

# %%
dfs = pd.DataFrame(df_pca)

# %%
dfs.head()
# Out:
#           0         1         2
# 0  0.065735 -0.558298  1.559385
# 1  1.095942 -0.675566  0.457144
# 2 -0.002631 -1.323561 -1.737417
# 3 -2.135294 -0.564523  0.441224
# 4  0.019548 -1.229717 -1.041648

# %%
eigen_values = pca.explained_variance_
eigen_values
# Out:
# array([1.00480043, 0.9990792 , 0.99615263])

# %%
variance = pca.explained_variance_ratio_
variance
# Out:
# array([0.33492988, 0.33302282, 0.33204731])

# %%
dfs.head()
# Out:
#           0         1         2
# 0  0.065735 -0.558298  1.559385
# 1  1.095942 -0.675566  0.457144
# 2 -0.002631 -1.323561 -1.737417
# 3 -2.135294 -0.564523  0.441224
# 4  0.019548 -1.229717 -1.041648

# %%
dfs['codeVehicle'] = dfx['codeVehicle']
dfs['time'] = df['part_of_day']

# %%
dfs
# Out:
#               0         1         2  codeVehicle  time
# 0      0.065735 -0.558298  1.559385            0     0
# 1      1.095942 -0.675566  0.457144            4     2
# 2     -0.002631 -1.323561 -1.737417            1     3
# 3     -2.135294 -0.564523  0.441224            0     0
# 4      0.019548 -1.229717 -1.041648            2     1
# ...         ...       ...       ...          ...   ...
# 92995  1.620209  1.098884 -0.406314            2     2
# 92996 -0.772973  0.436095 -0.404859            2     1
# 92997 -1.784313 -0.053451 -0.580243            3     0
# 92998  1.081747  0.726616 -1.306608            0     0
# 92999 -0.919651  0.866085 -0.701978            4     1
#
# [93000 rows x 5 columns]

# %%
dfs_numpy = np.array(dfs)

# %%
salary_numpy = np.array(df['Booking Value'])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(dfs_numpy, salary_numpy, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()
model = lr_model.fit(xtrain, ytrain)

# %%
model
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error

# %%
mape = mean_absolute_percentage_error(ypred, ytest)
print(f'{mape:.2%}')
# Out:
# 56.71%

# %%
mae = mean_absolute_error(ypred, ytest)
print(f'{mae}')
# Out:
# 288.0133261447319
